# %% [markdown]
# # ex1_scientific1
#
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$

# %% [markdown]
# ## Bài làm
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2 # 0 to 15 point radii
# Out:
# CPU times: user 2 μs, sys: 0 ns, total: 2 μs
# Wall time: 5.25 μs

# %% [markdown]
# ### Mã kiểm tra dữ liệu

# %%
print(f"x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]")
print(f"y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]")
print(f"colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]")
print(f"area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]")
# Out:
# x: len=50, [0.02, 0.98]: 10 samples [[0.92989978 0.41360951 0.53498404 0.97645023 0.31039933 0.65991931
#  0.69928376 0.60317569 0.12018813 0.33972192]]
# y: len=50, [0.01, 0.97]: 10 samples [[0.63467401 0.63628012 0.39451539 0.77818674 0.78154102 0.6298341
#  0.92023972 0.25422998 0.46510952 0.61699368]]
# colors: len=50, [0.05, 0.99]: 10 samples [[0.16314618 0.25014563 0.13484451 0.42855365 0.23829532 0.47353717
#  0.61502377 0.18925482 0.91421246 0.75241555]]
# area: len=50, [0.00, 701.82]: 10 samples [[ 76.12297184 497.60977411 448.39205426 217.27205625 287.10458015
#  566.74384435  33.28457875  78.46313125 339.43913101 297.67225135]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ## Kết thúc
